# %%
import chess
import chess.pgn

# %%
pgn = open('sample.pgn')
game = chess.pgn.read_game(pgn)

# %%
game.headers
# Out:
# Headers(Event='Rated Bullet tournament https://lichess.org/tournament/yc1WW2Ox', Site='https://lichess.org/PpwPOZMq', Date='????.??.??', Round='?', White='Abbot', Black='Costello', Result='0-1', BlackElo='2000', BlackRatingDiff='+1', ECO='B30', Opening='Sicilian Defense: Old Sicilian', Termination='Time forfeit', TimeControl='300+0', UTCDate='2017.04.01', UTCTime='11:32:01', WhiteElo='2100', WhiteRatingDiff='-4', WhiteTitle='FM')

# %%
board = game.board()
board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1')

# %%
board.pop()
board.halfmove_clock
# Out:
# 3

# %%
display(board.fen())
display(board)
display(board.peek())
# Out:
# 'r1bqkbnr/pp1ppppp/2n5/2p5/2B1P3/5N2/PPPP1PPP/RNBQK2R b KQkq - 3 3'
# Board('r1bqkbnr/pp1ppppp/2n5/2p5/2B1P3/5N2/PPPP1PPP/RNBQK2R b KQkq - 3 3')
# Move.from_uci('f1c4')

# %%
game.mainline_moves()
for move in game.mainline_moves():
    print(move)
    board.push(move)
    display(board)
# Out:
# e2e4
# Board('rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR b KQkq - 0 1')
# c7c5
# Board('rnbqkbnr/pp1ppppp/8/2p5/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2')
# g1f3
# Board('rnbqkbnr/pp1ppppp/8/2p5/4P3/5N2/PPPP1PPP/RNBQKB1R b KQkq - 1 2')
# b8c6
# Board('r1bqkbnr/pp1ppppp/2n5/2p5/4P3/5N2/PPPP1PPP/RNBQKB1R w KQkq - 2 3')
# f1c4
# Board('r1bqkbnr/pp1ppppp/2n5/2p5/2B1P3/5N2/PPPP1PPP/RNBQK2R b KQkq - 3 3')
# e7e6
# Board('r1bqkbnr/pp1p1ppp/2n1p3/2p5/2B1P3/5N2/PPPP1PPP/RNBQK2R w KQkq - 0 4')
# c2c3
# Board('r1bqkbnr/pp1p1ppp/2n1p3/2p5/2B1P3/2P2N2/PP1P1PPP/RNBQK2R b KQkq - 0 4')
# b7b5
# Board('r1bqkbnr/p2p1ppp/2n1p3/1pp5/2B1P3/2P2N2/PP1P1PPP/RNBQK2R w KQkq - 0 5')
# c4b3
# Board('r1bqkbnr/p2p1ppp/2n1p3/1pp5/4P3/1BP2N2/PP1P1PPP/RNBQK2R b KQkq - 1 5')
# c5c4
# Board('r1bqkbnr/p2p1ppp/2n1p3/1p6/2p1P3/1BP2N2/PP1P1PPP/RNBQK2R w KQkq - 0 6')
# b3c2
# Board('r1bqkbnr/p2p1ppp/2n1p3/1p6/2p1P3/2P2N2/PPBP1PPP/RNBQK2R b KQkq - 1 6')
# a7a5
# ...

# %%
game.root().variation(0).comment
# Out:
# '[%eval 0.17] [%clk 0:00:30]'

# %%
dir(list(game.mainline_moves())[0])
# Out:
# ['__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'drop',
#  'from_square',
#  'from_uci',
#  'null',
#  'promotion',
#  'to_square',
#  'uci',
#  'xboard']

# %%
list(game.mainline_moves())[0].xboard()
# Out:
# 'e2e4'
